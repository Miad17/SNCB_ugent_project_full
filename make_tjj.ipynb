# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import os
import holidays
import datetime as dt
os.getcwd()
# Out:
# '/Users/miek/Documents/DS4B/DS4BThesisSNCB'

# %%
# read in data
new_stops = pd.read_parquet("~/Downloads/TJJ_PTCAR_PARQUET (ALL COMM. SNCB TRAINS)/testtjjgent2")

# %%
# filter only on departure station
starting_stop = new_stops[new_stops["PTCAR_ORD_NO"] == 101]

# create a new column with only the hour component of theoretical departure time
starting_stop['THR_DEP_hour'] = starting_stop['THR_DEP'].dt.hour

# filter the rows that have a departure time between 6:00-9:00 or 16:00-19:00
starting_stop = starting_stop[starting_stop['THR_DEP_hour'].between(6, 9) | starting_stop['THR_DEP_hour'].between(16, 19)]

starting_stop
# Out:
# /var/folders/xh/tvsq17cn5c5f3xr3pqpf29_r0000gn/T/ipykernel_3517/1214668340.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   starting_stop['THR_DEP_hour'] = starting_stop['THR_DEP'].dt.hour
#           REF_TOD_TRAIN_ID TRAIN_PREFIX  TRAIN_NUMBER TRAIN_DEPARTURE_DATE
# 1                 22956975         None          2967           2019-02-28  \
# 3                 23030624         None          2968           2019-03-13
# 9                 22957754         None          2868           2019-02-28
# 11                22895587         None          3329           2019-02-17
# 14                22956972         None          2966           2019-02-28
# ...                    ...          ...           ...                  ...
# ...

# %%
peak_stops = new_stops[new_stops['REF_TOD_TRAIN_ID'].isin(starting_stop['REF_TOD_TRAIN_ID'])]
peak_stops
# Out:
#           REF_TOD_TRAIN_ID TRAIN_PREFIX  TRAIN_NUMBER TRAIN_DEPARTURE_DATE
# 0                 22757789         None          7607           2019-01-25  \
# 1                 22956975         None          2967           2019-02-28
# 2                 22800241         None          5366           2019-02-01
# 3                 23030624         None          2968           2019-03-13
# 7                 22757839         None          5909           2019-01-25
# ...                    ...          ...           ...                  ...
# 61345671          31326842         None          5009           2022-10-28
# 61345675          31637371         None          2206           2022-12-10
# 61345677          31325383         None          2641           2022-10-28
# 61345679          31636558         None          4338           2022-12-10
# 61345683          31326770         None          5468           2022-10-28
#
# ...

# %%
peak_stops.to_parquet("~/Downloads/TJJ_PTCAR_PARQUET (PEAK COMM. SNCB TRAINS)/testtjjgent2.parquet")
