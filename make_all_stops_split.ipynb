# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import os
import holidays
import datetime as dt
os.getcwd()
# Out:
# '/Users/miek/Documents/DS4B/DS4BThesisSNCB'

# %%
stops = pd.read_parquet("~/Downloads/all_stops_ungrouped/comm_stops_ungrouped.parquet")
stops
# Out:
#           REF_TOD_TRAIN_ID  TRAIN_NUMBER TRAIN_DEPARTURE_DATE  REF_PTCAR_NO
# 0                 22956975          2967           2019-02-28            37  \
# 1                 23030624          2968           2019-03-13            37
# 2                 22787493          3343           2019-01-30            37
# 3                 22957754          2868           2019-02-28            37
# 4                 22804611          5944           2019-02-01           641
# ...                    ...           ...                  ...           ...
# 58298859          31329661          2627           2022-10-28           715
# 58298860          31325182          2131           2022-10-28            70
# 58298861          31326770          5468           2022-10-28           726
# 58298862          31330053           555           2022-10-28           455
# 58298863          31329980          5561           2022-10-28           726
#
# ...

# %%
stops.columns
# Out:
# Index(['REF_TOD_TRAIN_ID', 'TRAIN_NUMBER', 'TRAIN_DEPARTURE_DATE',
#        'REF_PTCAR_NO', 'PTCAR_ORD_NO', 'THR_ARR', 'THR_DEP', 'HR_ARR',
#        'HR_DEP', 'EH_ARR', 'EH_DEP', 'COMMERCIAL_STOP_NATURE',
#        'DEPARTURE_REF_LINE_SECTION_NO', 'LINE', 'IDENTIFICATOR', 'YEAR_DEP',
#        'month', 'season', 'weekend', 'holiday', 'dep_hour_origin',
#        'day_origin', 'date_origin', 'start_lifetime', 'end_lifetime',
#        'arr_hour_terminus', 'p_indicator'],
#       dtype='object')

# %%
# Create DataFrames for each time period
stops_pre_covid = stops[stops['date_origin'] < pd.to_datetime('2020-03-18')].reset_index()
stops_pre_covid = stops_pre_covid.drop(columns='index')

stops_during_covid = stops[(stops['date_origin'] >= pd.to_datetime('2020-03-18')) & (stops['date_origin'] <= pd.to_datetime('2022-05-11'))].reset_index()
stops_during_covid = stops_during_covid.drop(columns='index')

stops_post_covid = stops[stops['date_origin'] > pd.to_datetime('2022-05-11')].reset_index()
stops_post_covid = stops_post_covid.drop(columns='index')

# %%
stops_during_covid
# Out:
#           REF_TOD_TRAIN_ID  TRAIN_NUMBER TRAIN_DEPARTURE_DATE  REF_PTCAR_NO
# 0                 26482881          5381           2020-10-21           349  \
# 1                 26482881          5381           2020-10-21           777
# 2                 26486098          5056           2020-10-21           769
# 3                 26485388          4723           2020-10-21           769
# 4                 26483906          9692           2020-10-21            88
# ...                    ...           ...                  ...           ...
# 28844030          27231495          3027           2021-02-22          1088
# 28844031          27413903           723           2021-03-24          1088
# 28844032          27228803          1819           2021-02-22          1088
# 28844033          27230130           739           2021-02-22          1088
# 28844034          26975184           411           2021-01-12           221
#
# ...

# %%
# make parquets
stops_pre_covid.to_parquet("~/Downloads/all_stops_ungrouped/comm_stops_pre_covid.parquet")
stops_during_covid.to_parquet("~/Downloads/all_stops_ungrouped/comm_stops_during_covid.parquet")
stops_post_covid.to_parquet("~/Downloads/all_stops_ungrouped/comm_stops_post_covid.parquet")
